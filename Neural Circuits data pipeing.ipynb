# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

batch_size = 25
train_loader = torch.utils.data.DataLoader(
        datasets.MNIST('../data', train=True, download=True,
                       transform=transforms.ToTensor()),
        batch_size = batch_size, shuffle=True)

from random import randint

print("kk")


##### TODO ######
# Circuit picking (all the reshapes and stuff)
# Circuit dropout
# Initial connection
# Out:
# kk

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
if device != 'cpu':
    torch.set_default_tensor_type('torch.cuda.FloatTensor')

num_classes=10

# %%
class CircuitNet(nn.Module):
    def __init__(self,circuit_dropout=0.5,circuit_ban_rate = 0.3,num_classes=12):
        super(CircuitNet, self).__init__()
        
        self.circuit_ban_rate = circuit_ban_rate
        self.circuit_dropout = circuit_dropout
        self.state_size = 100
        self.num_lstm_layers = 3
        
        #monitor use of each circuit to balance training
        self.used_circuits = np.zeros([40,2])
        for i in range(40):
            self.used_circuits[i][0] = i
        
        
        
        self.circuits_to_use = 10
        self.n_circuits = 20
        self.circuit_in_dim = 25
        
        
        #circuit picker
        self.circuit_picker = nn.Sequential(
            nn.Conv2d(1, 16, 3, stride=1, padding=1),  
            nn.ReLU(True),
            nn.BatchNorm2d(16),
            nn.MaxPool2d(2, stride=2),  
            nn.Conv2d(16, 8, 3, stride=1, padding=1),  
            nn.ReLU(True),
            nn.BatchNorm2d(8),
            nn.MaxPool2d(2, stride=2)
        )
        self.circuit_picker_out = nn.Linear(8*7*7, (self.n_circuits *  self.circuits_to_use))
        
        #data pipe
        self.data_pipe = nn.Sequential(
            nn.Conv2d(1, 16, 4, stride=1, padding=1),  
            nn.ReLU(True),
            nn.BatchNorm2d(16),
            nn.MaxPool2d(2, stride=2),  
            nn.Conv2d(16, 32, 4, stride=1, padding=1),  
            nn.ReLU(True),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2, stride=2)
        )
        self.data_pipe_out = nn.Linear(32*6*6, (self.circuits_to_use *  self.circuit_in_dim))
        
            
        self.circuits = []
        #define circuits
        for i in range(self.n_circuits):
        
            
            self.circuits.append(nn.Sequential(
                nn.Conv1d(1, 8, kernel_size=5, stride=1, padding=0),
                nn.BatchNorm1d(8),
                nn.ReLU(True),
                nn.MaxPool1d(kernel_size=2, stride=2),
            
                nn.Conv1d(8, 16, kernel_size=5, stride=1, padding=0),
                nn.BatchNorm1d(16),
                nn.ReLU(True),
                nn.MaxPool1d(kernel_size=2, stride=2)))
        
        
        #final circuit to prediction
        self.output = nn.Sequential(
            nn.Linear(16*30, 400),
            nn.Linear(400, 10))
        
    #init hidden state for lstm layer
    def init_hidden(self):
        return (torch.zeros(self.num_lstm_layers,1, self.state_size, device=device),
                torch.zeros(self.num_lstm_layers,1, self.state_size, device=device))
        
    def forward(self, x, verbose):
        x_flat = x.view(x.size(0),1, -1)
        circuit_pick = self.circuit_picker(x)
        circuit_pick = circuit_pick.view(circuit_pick.size(0), -1)
        circuit_pick = self.circuit_picker_out(circuit_pick)
        circuit_pick = circuit_pick.view(circuit_pick.size(0),self.circuits_to_use,self.n_circuits)
        circuit_pick = circuit_pick.max(2)[1]
        circuit_pick_padded = F.pad(circuit_pick,(0,18)).unsqueeze(1).unsqueeze(1)
        circuit_pick_padded = circuit_pick_padded.type(torch.cuda.FloatTensor)
        
        data_pipe_in = torch.cat((circuit_pick_padded,x),2)
        data_pipe = self.data_pipe(data_pipe_in)
        data_pipe = data_pipe.view(data_pipe.size(0), -1)
        
        data_pipe = self.data_pipe_out(data_pipe)
        data_pipe = data_pipe.view(data_pipe.size(0),self.circuits_to_use,self.circuit_in_dim)
        bans = np.random.randint(self.n_circuits,size=int(self.circuit_ban_rate*self.n_circuits))
        circuit_out = []
        for i in range(self.circuits_to_use):
            circuit_idx = circuit_pick[:,i]
            if(verbose):
                print(str(circuit_idx))
                
            batch = []
            for b in range(batch_size):
                circuit = self.circuits[circuit_idx[b]](data_pipe[b][i].unsqueeze(0).unsqueeze(0))
                
                #apply dropout
                if randint(1,100) < self.circuit_dropout*100 or circuit_idx[b] in bans:
                    circuit = torch.zeros(circuit.shape,device=device)  
                
                batch.append(circuit)
            batch = torch.cat(batch,0)
            circuit_out.append(batch)
        circuit_out = torch.cat(circuit_out,2)
        
        
        circuit_out_flat = circuit_out.view(circuit_out.size(0), -1)
        out = self.output(circuit_out_flat)
        #print(output.shape)
        #######
        #connect = self.connection(x_flat, verbose)
        #bridge = self.circuit_bridge(connect).unsqueeze(1)
        #print(bridge.shape)
        #connect1 = self.connection(bridge, verbose)
        
        ######
        
        #out = self.output(connect)
        return out
    
        

if device != 'cpu':
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
model = CircuitNet(circuit_dropout=0.4, circuit_ban_rate = 0.4).to(device)
torch.set_default_tensor_type('torch.FloatTensor')

for batch_idx, (data, target) in enumerate(train_loader):
    data, target = data.to(device), target.to(device)
    output = model(data,False)
    break

# %% [raw]
# if device != 'cpu':
#     torch.set_default_tensor_type('torch.cuda.FloatTensor')
# model = CircuitNet().to(device)
# torch.set_default_tensor_type('torch.FloatTensor')
#
# for batch_idx, (data, target) in enumerate(train_loader):
#     #if device != 'cpu':
#     #    torch.set_default_tensor_type('torch.cuda.FloatTensor')
#     data, target = data.to(device), target.to(device)
#     #print(data)
#     output = model(data)
#     break

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
model.train()
iter_print = 25
for batch_idx, (data, target) in enumerate(train_loader):
    data, target = data.to(device), target.to(device)
    optimizer.zero_grad()
    verbose = False
    if(batch_idx % iter_print == 0):
        verbose = False
    output = model(data,verbose)
    loss =  nn.CrossEntropyLoss()(output, target)
    #loss = (output-target)**2
    loss.backward(retain_graph=True)
    optimizer.step()
    
    model.hidden = model.init_hidden()
    if(batch_idx % iter_print == 0):
        print("Index : {}  Loss : {:.5f}  Real : {}  Pred : {}".format(batch_idx,loss[0],target[0:4],output[0:4].max(1)[1]))
# Out:
# /home/liam/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# Index : 0  Loss : 2.30596  Real : tensor([ 3,  6,  3,  3], device='cuda:0')  Pred : tensor([ 2,  6,  8,  0], device='cuda:0')
# Index : 25  Loss : 2.02217  Real : tensor([ 4,  2,  3,  8], device='cuda:0')  Pred : tensor([ 7,  3,  4,  9], device='cuda:0')
# Index : 50  Loss : 1.57218  Real : tensor([ 3,  3,  2,  6], device='cuda:0')  Pred : tensor([ 6,  6,  6,  6], device='cuda:0')
# Index : 75  Loss : 1.48286  Real : tensor([ 2,  5,  5,  4], device='cuda:0')  Pred : tensor([ 2,  3,  5,  4], device='cuda:0')
# Index : 100  Loss : 1.01163  Real : tensor([ 4,  8,  9,  6], device='cuda:0')  Pred : tensor([ 9,  6,  9,  0], device='cuda:0')
# Index : 125  Loss : 0.86691  Real : tensor([ 7,  8,  3,  9], device='cuda:0')  Pred : tensor([ 7,  1,  3,  9], device='cuda:0')
# Index : 150  Loss : 0.81922  Real : tensor([ 5,  3,  4,  9], device='cuda:0')  Pred : tensor([ 5,  3,  4,  9], device='cuda:0')
# Index : 175  Loss : 0.75782  Real : tensor([ 3,  6,  9,  1], device='cuda:0')  Pred : tensor([ 3,  0,  9,  1], device='cuda:0')
# Index : 200  Loss : 0.84736  Real : tensor([ 0,  9,  0,  2], device='cuda:0')  Pred : tensor([ 0,  9,  0,  2], device='cuda:0')
# Index : 225  Loss : 0.90501  Real : tensor([ 6,  1,  6,  7], device='cuda:0')  Pred : tensor([ 1,  1,  6,  9], device='cuda:0')
# Index : 250  Loss : 0.67552  Real : tensor([ 0,  0,  1,  4], device='cuda:0')  Pred : tensor([ 0,  0,  1,  4], device='cuda:0')
# Index : 275  Loss : 0.68698  Real : tensor([ 5,  4,  1,  0], device='cuda:0')  Pred : tensor([ 5,  9,  1,  0], device='cuda:0')
# Index : 300  Loss : 0.86612  Real : tensor([ 7,  8,  2,  9], device='cuda:0')  Pred : tensor([ 7,  9,  2,  9], device='cuda:0')
# Index : 325  Loss : 0.59110  Real : tensor([ 2,  7,  1,  7], device='cuda:0')  Pred : tensor([ 2,  7,  1,  2], device='cuda:0')
# Index : 350  Loss : 0.72885  Real : tensor([ 3,  4,  6,  4], device='cuda:0')  Pred : tensor([ 3,  4,  6,  9], device='cuda:0')
# Index : 375  Loss : 0.49582  Real : tensor([ 2,  7,  9,  0], device='cuda:0')  Pred : tensor([ 2,  7,  9,  0], device='cuda:0')
# Index : 400  Loss : 0.16337  Real : tensor([ 0,  1,  6,  3], device='cuda:0')  Pred : tensor([ 0,  1,  6,  3], device='cuda:0')
# Index : 425  Loss : 0.47947  Real : tensor([ 0,  2,  4,  0], device='cuda:0')  Pred : tensor([ 0,  0,  4,  0], device='cuda:0')
# Index : 450  Loss : 0.30601  Real : tensor([ 2,  9,  8,  5], device='cuda:0')  Pred : tensor([ 2,  9,  3,  5], device='cuda:0')
# Index : 475  Loss : 0.52439  Real : tensor([ 8,  0,  2,  6], device='cuda:0')  Pred : tensor([ 3,  0,  7,  6], device='cuda:0')
# Index : 500  Loss : 0.49725  Real : tensor([ 0,  2,  5,  8], device='cuda:0')  Pred : tensor([ 0,  0,  5,  8], device='cuda:0')
# Index : 525  Loss : 0.21092  Real : tensor([ 9,  7,  4,  1], device='cuda:0')  Pred : tensor([ 5,  7,  4,  1], device='cuda:0')
# Index : 550  Loss : 0.80106  Real : tensor([ 5,  7,  9,  7], device='cuda:0')  Pred : tensor([ 5,  7,  9,  7], device='cuda:0')
# Index : 575  Loss : 0.62698  Real : tensor([ 4,  1,  1,  7], device='cuda:0')  Pred : tensor([ 4,  6,  1,  9], device='cuda:0')
# Index : 600  Loss : 0.30896  Real : tensor([ 7,  1,  2,  2], device='cuda:0')  Pred : tensor([ 0,  1,  8,  2], device='cuda:0')
# Index : 625  Loss : 0.19577  Real : tensor([ 0,  0,  7,  3], device='cuda:0')  Pred : tensor([ 0,  0,  7,  3], device='cuda:0')
# Index : 650  Loss : 0.57559  Real : tensor([ 8,  3,  5,  4], device='cuda:0')  Pred : tensor([ 8,  3,  5,  2], device='cuda:0')
# Index : 675  Loss : 0.35812  Real : tensor([ 6,  1,  3,  5], device='cuda:0')  Pred : tensor([ 6,  1,  3,  5], device='cuda:0')
# Index : 700  Loss : 0.09212  Real : tensor([ 1,  1,  7,  0], device='cuda:0')  Pred : tensor([ 1,  1,  7,  0], device='cuda:0')
# Index : 725  Loss : 0.31658  Real : tensor([ 1,  0,  8,  4], device='cuda:0')  Pred : tensor([ 1,  0,  8,  4], device='cuda:0')
# Index : 750  Loss : 1.06278  Real : tensor([ 2,  6,  9,  7], device='cuda:0')  Pred : tensor([ 2,  6,  8,  7], device='cuda:0')
# Index : 775  Loss : 0.19548  Real : tensor([ 8,  0,  4,  4], device='cuda:0')  Pred : tensor([ 8,  0,  4,  4], device='cuda:0')
# Index : 800  Loss : 0.80212  Real : tensor([ 2,  1,  6,  5], device='cuda:0')  Pred : tensor([ 2,  1,  6,  5], device='cuda:0')
# Index : 825  Loss : 0.20101  Real : tensor([ 4,  0,  6,  5], device='cuda:0')  Pred : tensor([ 4,  0,  5,  5], device='cuda:0')
# Index : 850  Loss : 0.08297  Real : tensor([ 0,  3,  8,  3], device='cuda:0')  Pred : tensor([ 0,  3,  8,  3], device='cuda:0')
# Index : 875  Loss : 0.25047  Real : tensor([ 7,  0,  5,  1], device='cuda:0')  Pred : tensor([ 7,  0,  3,  1], device='cuda:0')
# Index : 900  Loss : 0.12912  Real : tensor([ 5,  2,  3,  2], device='cuda:0')  Pred : tensor([ 5,  2,  3,  2], device='cuda:0')
# Index : 925  Loss : 0.20649  Real : tensor([ 4,  3,  8,  4], device='cuda:0')  Pred : tensor([ 4,  3,  8,  4], device='cuda:0')
# Index : 950  Loss : 0.19757  Real : tensor([ 3,  9,  4,  3], device='cuda:0')  Pred : tensor([ 3,  9,  4,  3], device='cuda:0')
# Index : 975  Loss : 0.67706  Real : tensor([ 6,  7,  5,  1], device='cuda:0')  Pred : tensor([ 6,  7,  5,  1], device='cuda:0')
# Index : 1000  Loss : 0.14044  Real : tensor([ 6,  6,  7,  6], device='cuda:0')  Pred : tensor([ 6,  6,  7,  6], device='cuda:0')
# Index : 1025  Loss : 0.48020  Real : tensor([ 1,  1,  7,  8], device='cuda:0')  Pred : tensor([ 1,  1,  7,  9], device='cuda:0')
# Index : 1050  Loss : 0.51446  Real : tensor([ 0,  4,  1,  5], device='cuda:0')  Pred : tensor([ 0,  4,  3,  5], device='cuda:0')
# Index : 1075  Loss : 0.60024  Real : tensor([ 2,  7,  3,  5], device='cuda:0')  Pred : tensor([ 2,  7,  3,  5], device='cuda:0')
# Index : 1100  Loss : 0.62843  Real : tensor([ 9,  9,  8,  0], device='cuda:0')  Pred : tensor([ 7,  9,  9,  0], device='cuda:0')
# Index : 1125  Loss : 0.17583  Real : tensor([ 2,  4,  7,  7], device='cuda:0')  Pred : tensor([ 2,  4,  7,  2], device='cuda:0')
# Index : 1150  Loss : 0.17765  Real : tensor([ 2,  8,  8,  3], device='cuda:0')  Pred : tensor([ 2,  8,  8,  3], device='cuda:0')
# Index : 1175  Loss : 0.03288  Real : tensor([ 2,  0,  1,  9], device='cuda:0')  Pred : tensor([ 2,  0,  1,  9], device='cuda:0')
# Index : 1200  Loss : 0.33041  Real : tensor([ 4,  7,  5,  2], device='cuda:0')  Pred : tensor([ 4,  7,  5,  2], device='cuda:0')
# Index : 1225  Loss : 0.24990  Real : tensor([ 9,  4,  3,  0], device='cuda:0')  Pred : tensor([ 9,  4,  3,  0], device='cuda:0')
# Index : 1250  Loss : 0.08076  Real : tensor([ 0,  8,  3,  5], device='cuda:0')  Pred : tensor([ 0,  8,  3,  5], device='cuda:0')
# Index : 1275  Loss : 0.31097  Real : tensor([ 4,  2,  9,  0], device='cuda:0')  Pred : tensor([ 4,  2,  9,  6], device='cuda:0')
# Index : 1300  Loss : 0.22316  Real : tensor([ 4,  0,  6,  2], device='cuda:0')  Pred : tensor([ 4,  0,  1,  8], device='cuda:0')
# Index : 1325  Loss : 0.06096  Real : tensor([ 1,  2,  6,  9], device='cuda:0')  Pred : tensor([ 1,  2,  6,  9], device='cuda:0')
# Index : 1350  Loss : 0.12003  Real : tensor([ 7,  0,  1,  3], device='cuda:0')  Pred : tensor([ 7,  0,  1,  3], device='cuda:0')
# Index : 1375  Loss : 0.01856  Real : tensor([ 0,  4,  3,  9], device='cuda:0')  Pred : tensor([ 0,  4,  3,  9], device='cuda:0')
# Index : 1400  Loss : 0.23337  Real : tensor([ 9,  7,  4,  2], device='cuda:0')  Pred : tensor([ 9,  7,  4,  2], device='cuda:0')
# Index : 1425  Loss : 0.85997  Real : tensor([ 0,  1,  5,  9], device='cuda:0')  Pred : tensor([ 0,  1,  5,  9], device='cuda:0')
# Index : 1450  Loss : 0.50990  Real : tensor([ 5,  3,  2,  2], device='cuda:0')  Pred : tensor([ 5,  3,  7,  8], device='cuda:0')
# Index : 1475  Loss : 0.24988  Real : tensor([ 6,  2,  0,  2], device='cuda:0')  Pred : tensor([ 6,  2,  0,  2], device='cuda:0')
# Index : 1500  Loss : 0.06321  Real : tensor([ 9,  9,  0,  6], device='cuda:0')  Pred : tensor([ 9,  9,  0,  6], device='cuda:0')
# Index : 1525  Loss : 0.17101  Real : tensor([ 2,  5,  6,  1], device='cuda:0')  Pred : tensor([ 2,  5,  6,  1], device='cuda:0')
# Index : 1550  Loss : 0.34504  Real : tensor([ 8,  3,  9,  9], device='cuda:0')  Pred : tensor([ 8,  2,  9,  9], device='cuda:0')
# Index : 1575  Loss : 0.26713  Real : tensor([ 4,  6,  9,  4], device='cuda:0')  Pred : tensor([ 4,  6,  9,  4], device='cuda:0')
# Index : 1600  Loss : 0.24281  Real : tensor([ 1,  6,  2,  0], device='cuda:0')  Pred : tensor([ 2,  8,  2,  0], device='cuda:0')
# Index : 1625  Loss : 0.14062  Real : tensor([ 2,  6,  9,  8], device='cuda:0')  Pred : tensor([ 2,  6,  9,  8], device='cuda:0')
# Index : 1650  Loss : 0.19818  Real : tensor([ 5,  7,  1,  5], device='cuda:0')  Pred : tensor([ 5,  7,  1,  5], device='cuda:0')
# Index : 1675  Loss : 0.13553  Real : tensor([ 3,  8,  3,  6], device='cuda:0')  Pred : tensor([ 3,  8,  3,  6], device='cuda:0')
# Index : 1700  Loss : 0.22006  Real : tensor([ 1,  0,  7,  2], device='cuda:0')  Pred : tensor([ 1,  0,  7,  2], device='cuda:0')
# Index : 1725  Loss : 0.27368  Real : tensor([ 1,  0,  9,  9], device='cuda:0')  Pred : tensor([ 1,  0,  9,  9], device='cuda:0')
# Index : 1750  Loss : 0.05708  Real : tensor([ 8,  9,  1,  3], device='cuda:0')  Pred : tensor([ 8,  9,  1,  3], device='cuda:0')
# Index : 1775  Loss : 0.09944  Real : tensor([ 3,  2,  1,  1], device='cuda:0')  Pred : tensor([ 3,  2,  1,  1], device='cuda:0')
# Index : 1800  Loss : 0.04029  Real : tensor([ 1,  7,  8,  8], device='cuda:0')  Pred : tensor([ 1,  7,  8,  8], device='cuda:0')
# Index : 1825  Loss : 0.42249  Real : tensor([ 3,  9,  1,  8], device='cuda:0')  Pred : tensor([ 1,  9,  1,  8], device='cuda:0')
# Index : 1850  Loss : 0.05383  Real : tensor([ 2,  2,  1,  6], device='cuda:0')  Pred : tensor([ 2,  2,  1,  6], device='cuda:0')
# Index : 1875  Loss : 0.10120  Real : tensor([ 6,  7,  0,  1], device='cuda:0')  Pred : tensor([ 6,  7,  0,  1], device='cuda:0')
# Index : 1900  Loss : 0.38546  Real : tensor([ 2,  8,  0,  8], device='cuda:0')  Pred : tensor([ 2,  6,  0,  8], device='cuda:0')
# Index : 1925  Loss : 0.23585  Real : tensor([ 8,  7,  7,  8], device='cuda:0')  Pred : tensor([ 6,  7,  7,  8], device='cuda:0')
# Index : 1950  Loss : 0.17402  Real : tensor([ 4,  4,  7,  7], device='cuda:0')  Pred : tensor([ 4,  4,  7,  7], device='cuda:0')
# Index : 1975  Loss : 0.01324  Real : tensor([ 9,  4,  5,  8], device='cuda:0')  Pred : tensor([ 9,  4,  5,  8], device='cuda:0')
# Index : 2000  Loss : 0.61040  Real : tensor([ 6,  3,  5,  1], device='cuda:0')  Pred : tensor([ 6,  3,  5,  1], device='cuda:0')
# Index : 2025  Loss : 0.57061  Real : tensor([ 9,  0,  5,  9], device='cuda:0')  Pred : tensor([ 9,  0,  5,  2], device='cuda:0')
# Index : 2050  Loss : 0.09296  Real : tensor([ 8,  4,  3,  7], device='cuda:0')  Pred : tensor([ 8,  4,  3,  7], device='cuda:0')
# Index : 2075  Loss : 0.17919  Real : tensor([ 1,  1,  6,  1], device='cuda:0')  Pred : tensor([ 1,  1,  6,  1], device='cuda:0')
# Index : 2100  Loss : 0.18420  Real : tensor([ 7,  4,  3,  4], device='cuda:0')  Pred : tensor([ 7,  4,  3,  4], device='cuda:0')
# Index : 2125  Loss : 0.05171  Real : tensor([ 1,  2,  5,  9], device='cuda:0')  Pred : tensor([ 1,  2,  5,  9], device='cuda:0')
# Index : 2150  Loss : 0.25266  Real : tensor([ 9,  9,  4,  4], device='cuda:0')  Pred : tensor([ 9,  9,  4,  4], device='cuda:0')
# Index : 2175  Loss : 0.10035  Real : tensor([ 5,  9,  7,  3], device='cuda:0')  Pred : tensor([ 5,  9,  7,  3], device='cuda:0')
# Index : 2200  Loss : 0.18148  Real : tensor([ 9,  8,  8,  0], device='cuda:0')  Pred : tensor([ 9,  8,  8,  0], device='cuda:0')
# Index : 2225  Loss : 0.12816  Real : tensor([ 9,  9,  6,  0], device='cuda:0')  Pred : tensor([ 9,  9,  6,  0], device='cuda:0')
# Index : 2250  Loss : 0.05109  Real : tensor([ 7,  6,  8,  6], device='cuda:0')  Pred : tensor([ 7,  6,  8,  6], device='cuda:0')
# Index : 2275  Loss : 0.03846  Real : tensor([ 6,  9,  7,  1], device='cuda:0')  Pred : tensor([ 6,  9,  7,  1], device='cuda:0')
# Index : 2300  Loss : 0.76016  Real : tensor([ 9,  2,  8,  6], device='cuda:0')  Pred : tensor([ 9,  2,  8,  6], device='cuda:0')
# Index : 2325  Loss : 0.23294  Real : tensor([ 2,  5,  2,  9], device='cuda:0')  Pred : tensor([ 2,  3,  2,  9], device='cuda:0')
# Index : 2350  Loss : 0.07229  Real : tensor([ 3,  4,  8,  7], device='cuda:0')  Pred : tensor([ 3,  4,  8,  7], device='cuda:0')
# Index : 2375  Loss : 0.39705  Real : tensor([ 7,  7,  7,  6], device='cuda:0')  Pred : tensor([ 7,  7,  7,  6], device='cuda:0')
